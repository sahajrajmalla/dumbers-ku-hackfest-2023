# %%
import pandas as pd

# %%
project_carbon = pd.read_csv("project_carbon.csv")

# %%
project_carbon.columns = [i.replace(" ","_").strip().lower() for i in project_carbon.columns]

# %%
project_carbon.to_csv("project_carbon.csv", index=False)

# %%
project_carbon
# Out:
#      project_id                 project_name   latitude   longitude  \
# 0             1   Munoz, Perez and Alexander  75.329037   -1.664521
# 1             2                 Edwards-Cobb   9.057154  -74.638780
# 2             3                  Maynard Inc  20.261056   46.350681
# 3             4                   Odom-Davis -30.488494  128.497142
# 4             5                Ayers-Bernard -83.535560 -166.767316
# ..          ...                          ...        ...         ...
# 995         996                 Harvey-Brown  11.685669  125.454312
# 996         997  Chavez, Mcmillan and Landry  47.778506 -162.662807
# 997         998                   Walker Ltd -61.992423   36.166900
# 998         999                  Hoffman LLC  29.222957 -101.561061
# 999        1000              Austin-Clements -25.184503  -89.233580
#
#     project_type  start_date    end_date  budget_($)  emission_(co2e)  \
# 0        Housing  2023-06-28  2026-01-19  5341346.61           199.44
# ...
