# %%
import pandas as pd

# Read CSV file into a DataFrame
df = pd.read_csv('/users/smalla/dumbers-ku-hackfest-2023/backend/data/development_energy_data.csv')

df
# Out:
#     Development Category  Tenure (years)  Size (1-10)  \
# 0                 bridge              38            4
# 1                housing               7           10
# 2    residential housing              14            4
# 3                factory              17            6
# 4                 bridge              14            1
# ..                   ...             ...          ...
# 995               bridge               5            6
# 996  residential housing              48            1
# 997               bridge              36           10
# 998               bridge              20            4
# 999  residential housing              32            9
#
#      Energy Type (1-Renewable, 0-Non-Renewable)  Energy Consumption (units)
# 0                                             1                 7691.312199
# 1                                             1                 2667.063237
# 2                                             0                 8882.462273
# ...

# %%
group_df = df.groupby("Development Category").agg("mean")

# %%
group_df.columns = [i.lower().replace(" ", "_") for i in group_df.columns]

# %%
group_df.reset_index(drop=False, inplace=True)

# %%
# Save the DataFrame to a JSON file
group_df.to_json('development_energy.json', orient='records')
