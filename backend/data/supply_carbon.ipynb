# %%
import pandas as pd

# %%
supply = pd.read_csv("supply.csv")

# %%
supply.columns = [i.lower().replace(" ", "_") for i in supply.columns]

# %%
supply.columns = ['product_id', 'product_name', 'supplier', 'latitude',
       'longitude', 'destination_latitude', 'destination_longitude',
       'transportation_method', 'emission_(co2e)', 'date']

# %%
supply.to_csv("supply.csv", index=False)

# %%
supply
# Out:
#      product_id                                    product_name  \
# 0             1                     Darkcyan Seize B2C Networks
# 1             2               Gold Engage Seamless Applications
# 2             3         Slategray Reinvent Global Supply-Chains
# 3             4        Whitesmoke Architect Cross-Media Content
# 4             5    Darkcyan Envisioneer Synergistic Initiatives
# ..          ...                                             ...
# 995         996                  Navy Synergize Real-Time Users
# 996         997  Cornsilk Iterate Cross-Platform Info-Mediaries
# 997         998                  Papayawhip Harness Viral Users
# 998         999        Mediumseagreen Benchmark Virtual Metrics
# 999        1000     Midnightblue Redefine Holistic Partnerships
#
#                         supplier   latitude   longitude  destination_latitude  \
# 0                      Zhang PLC -85.817027   66.488162            -18.387223
# ...
