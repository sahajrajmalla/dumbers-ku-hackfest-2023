# %%
import pandas as pd

# Read CSV file into a DataFrame
df = pd.read_csv('organism.csv')

# %%
df.columns = [i.lower().replace(" ", "_") for i in df.columns]

# %%
df.to_csv('organism.csv', index=False)

# %%
df
# Out:
#     species_name   latitude   longitude habitat_type  population_size  \
# 0          Hyena  81.471609  -32.129441    Grassland              258
# 1           Lion -70.455426  -78.417732      Wetland              447
# 2        Cheetah  49.734316  143.489220       Forest              714
# 3           Lion -26.505765  -68.012184       Desert               33
# 4       Elephant -73.944327   23.147967    Grassland              943
# ..           ...        ...         ...          ...              ...
# 995        Zebra  78.994209 -163.506137       Desert              322
# 996      Giraffe -31.369892    3.302485       Desert              484
# 997        Zebra  51.839720  -66.752150       Desert              963
# 998     Elephant  52.042546 -160.149627      Wetland              407
# 999         Lion -32.044023  -41.739753    Grassland              688
#
#     date_of_observation observation_method          threat_status
# ...
